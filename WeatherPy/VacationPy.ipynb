# %%
#! pip3 install geoviews
# Out:
# Requirement already satisfied: geoviews in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (1.9.6)
# Requirement already satisfied: packaging in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (23.0)
# Requirement already satisfied: bokeh<2.5,>=2.4.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (2.4.3)
# Requirement already satisfied: numpy in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (1.23.5)
# Requirement already satisfied: panel in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (0.14.2)
# Requirement already satisfied: param in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (1.12.3)
# Requirement already satisfied: shapely in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (2.0.0)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (0.21.1)
# Requirement already satisfied: holoviews>=1.14.2 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (1.15.4)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (6.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (4.4.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (6.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (9.4.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (3.1.2)
# Requirement already satisfied: pyshp>=2.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.6.3)
# Requirement already satisfied: pyproj>=3.0.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.4.1)
# Requirement already satisfied: colorcet in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.14.2->geoviews) (3.0.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.14.2->geoviews) (1.5.3)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.14.2->geoviews) (2.2.1)
# Requirement already satisfied: bleach in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (5.0.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (4.64.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (0.4.6)
# Requirement already satisfied: markdown in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (3.4.1)
# Requirement already satisfied: setuptools>=42 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (66.0.0)
# Requirement already satisfied: requests in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (2.28.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from Jinja2>=2.9->bokeh<2.5,>=2.4.0->geoviews) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.20.0->holoviews>=1.14.2->geoviews) (2022.7.1)
# Requirement already satisfied: certifi in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from pyproj>=3.0.0->cartopy>=0.18.0->geoviews) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from tqdm>=4.48.0->panel->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bleach->panel->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bleach->panel->geoviews) (0.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from requests->panel->geoviews) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from requests->panel->geoviews) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from requests->panel->geoviews) (3.4)

# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import geoviews as gv


# Import API key
from api_keys import geoapify_key

# %%
#! pip install cartopy
#! pip3 install geoviews
# Out:
# Requirement already satisfied: geoviews in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (1.9.6)
# Requirement already satisfied: bokeh<2.5,>=2.4.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (2.4.3)
# Requirement already satisfied: shapely in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (2.0.0)
# Requirement already satisfied: packaging in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (23.0)
# Requirement already satisfied: numpy in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (1.23.5)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (0.21.1)
# Requirement already satisfied: holoviews>=1.14.2 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (1.15.4)
# Requirement already satisfied: panel in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (0.14.2)
# Requirement already satisfied: param in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from geoviews) (1.12.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (4.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (6.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (3.1.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bokeh<2.5,>=2.4.0->geoviews) (9.4.0)
# Requirement already satisfied: pyproj>=3.0.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.4.1)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.6.2)
# Requirement already satisfied: pyshp>=2.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.14.2->geoviews) (1.5.2)
# Requirement already satisfied: colorcet in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.14.2->geoviews) (3.0.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from holoviews>=1.14.2->geoviews) (2.2.1)
# Requirement already satisfied: requests in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (2.28.2)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (0.4.6)
# Requirement already satisfied: setuptools>=42 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (66.0.0)
# Requirement already satisfied: markdown in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (3.4.1)
# Requirement already satisfied: bleach in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (5.0.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from panel->geoviews) (4.64.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from Jinja2>=2.9->bokeh<2.5,>=2.4.0->geoviews) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.20.0->holoviews>=1.14.2->geoviews) (2022.7.1)
# Requirement already satisfied: certifi in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from pyproj>=3.0.0->cartopy>=0.18.0->geoviews) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from tqdm>=4.48.0->panel->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bleach->panel->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from bleach->panel->geoviews) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from requests->panel->geoviews) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from requests->panel->geoviews) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\panth\anaconda3\envs\pythondata\lib\site-packages (from requests->panel->geoviews) (1.26.14)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head(50)
# Out:
#     City_ID                   City       Lat      Lng  Max Temp  Humidity  \
# 0         0                 vanimo  141.3028  -2.6741     25.27        87
# 1         1           quatre cocos   57.7625 -20.2078     25.06        89
# 2         2                  vaini -175.2000 -21.2000     30.09        84
# 3         3         port elizabeth   25.5701 -33.9180     23.39        92
# 4         4              busselton  115.3333 -33.6500     20.08        55
# 5         5                   mayo  -76.5119  38.8876      8.49        51
# 6         6                ahipara  173.1667 -35.1667     22.08        59
# 7         7                 albany  -73.9662  42.6001      3.71        83
# 8         8             butaritari  172.7902   3.0707     27.38        76
# 9         9                ushuaia  -68.3000 -54.8000     12.81        71
# 10       10                   kyra  111.9753  49.5776    -27.08        94
# 34           6        6.90      DM  1674251452
# 35          86        1.39      RU  1674251453
# 36           0       12.73      GL  1674251453
# 37           7        4.30      KG  1674251454
# 38          20        0.00      CA  1674251437
# 39         100        7.20      US  1674251424
# 40           0        5.14      IR  1674251454
# 41          75        2.57      CA  1674251455
# 42          79        2.75      NZ  1674251455
# 43          88        1.48      TZ  1674251456
# 44           3        5.91      CV  1674251456
# 45          94        1.81      ZA  1674251457
# 46           0       10.80      NO  1674251457
# 47         100        6.90      US  1674251458
# 48         100       14.32      RU  1674251458
# 49           2        6.47      AU  1674251459

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_df.hvplot.points('Lat', 'Lng', c = 'City', s = 'Humidity', geo = True, tiles=True)
# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lat,Lng]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

city_data_df = city_data_df.loc[city_data_df['Max Temp']  < 27 & (city_data_df["Max Temp"] > 21) & (city_data_df["Wind Speed"] < 4.5) & (city_data_df["Cloudiness"] == 0)]

# Drop any rows with null values
city_data_df = city_data_df.dropna()

# Display sample data
city_data_df


# narrowed_city_df = city_data_df.loc[
#     (city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21) \
#     & (city_data_df["Wind Speed"] < 4.5) \
#     & (city_data_df["Cloudiness"] == 0)
#]
# Out:
#      City_ID           City       Lat      Lng  Max Temp  Humidity  \
# 10        10           kyra  111.9753  49.5776    -27.08        94
# 17        17       uvelskiy   61.3574  54.4446    -15.67        82
# 24        24     chokurdakh  147.9167  70.6333    -34.79        99
# 26        26      sanmenxia  111.1814  34.7747     -2.32        53
# 28        28        qaanaaq  -69.3632  77.4840    -35.37        60
# ..       ...            ...       ...      ...       ...       ...
# 560      560  staraya russa   31.3608  57.9944     -0.30        94
# 561      561       vanavara  102.2797  60.3400    -45.25       100
# 564      564       bilibino  166.4372  68.0546    -37.89       100
# 565      565        yakeshi  120.7333  49.2833    -29.80        99
# 566      566   port-cartier  -66.8654  50.0334     -6.18        89
#
#      Cloudiness  Wind Speed Country        Date
# 10          100        1.82      RU  1674251441
# 17           35        2.51      RU  1674251443
# 24          100        3.17      RU  1674251447
# 26            0        0.68      CN  1674251448
# 28            0        3.71      GL  1674251449
# ..          ...         ...     ...         ...
# 560         100        2.73      RU  1674251717
# 561          58        1.72      RU  1674251718
# 564          96        0.67      RU  1674251719
# 565         100        0.24      CN  1674251720
# 566         100        2.32      CA  1674251721
#
# [139 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''
# Display sample data
hotel_df.head()
# Out:
#           City Country       Lat      Lng  Humidity Hotel Name
# 10        kyra      RU  111.9753  49.5776        94
# 17    uvelskiy      RU   61.3574  54.4446        82
# 24  chokurdakh      RU  147.9167  70.6333        99
# 26   sanmenxia      CN  111.1814  34.7747        53
# 28     qaanaaq      GL  -69.3632  77.4840        60

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "limit":20,
    "apiKey":geoapify_key, 
    "categories":"accommodation.hotel" #dont forget this 
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, 'Lng']
    longitude = hotel_df.loc[index, 'Lng']

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    #print(name_address)


    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]

    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# kyra - nearest hotel: No hotel found
# uvelskiy - nearest hotel: No hotel found
# chokurdakh - nearest hotel: No hotel found
# sanmenxia - nearest hotel: No hotel found
# qaanaaq - nearest hotel: No hotel found
# provideniya - nearest hotel: No hotel found
# nikolskoye - nearest hotel: No hotel found
# nanortalik - nearest hotel: Урал
# kyzyl-suu - nearest hotel: Karma hostel
# yellowknife - nearest hotel: No hotel found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[105], line 27
#      23 base_url = "https://api.geoapify.com/v2/places"
#      26 # Make and API request using the params dictionaty
# ---> 27 name_address = requests.get(base_url, params=params)
#      29 # Convert the API response to JSON format
#      30 name_address = name_address.json()
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\urllib3\connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File c:\Users\panth\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\ssl_.py:402, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400 if ca_certs or ca_cert_dir or ca_cert_data:
#     401     try:
# --> 402         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403     except (IOError, OSError) as e:
#     404         raise SSLError(e)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_df = hotel_df[hotel_df['Hotel Name'] != 'No hotel found']
hotel_df
hotel_df.hvplot.points('Lat', 'Lng', c = 'City', s = 'Humidity', geo = True, tiles=True, 
hover_cols=["Hotel Name", "Country"])
# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lat,Lng]   (City,Humidity,Hotel Name,Country)
